# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt


ftname = mpl.font_manager.FontProperties(fname='C:\Windows\Fonts\HMFMPYUN.TTF').get_name()
mpl.rc('font',family=ftname)
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['font.size']=20


# # 그래프 한글 출력하기
# mpl.rcParams['font.family'] ='HANCooljazzM'
# mpl.rcParams['axes.unicode_minus'] = False
# mpl.rcParams['font.size']=20


# 그래프 스타일 지정하기
plt.style.use('grayscale')
x = np.linspace(0,10,1000)
ig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x),'r', label='사인')
ax.plot(x, np.cos(x),'b', label='코사인')
ax.legend()
ax.grid()
plt.show()

# %%
# 그래프 스타일 지정하기
# plt.style.use('classic') # 고전 
# plt.style.use('seaborn-whitegrid')   # seaborn 세련
# plt.style.use('fivethirtyeight')   # 강조, 굵게
# plt.style.use('ggplot')   # R ggplot
# plt.style.use('bmh')    # 유명한 확률책 스타일 예제 - 해커스타일
# plt.style.use('dark_background')  # 프레젠테이션
# plt.style.use('grayscale')  # 회색조
# plt.style.use('seaborn-pastel')  # 파스텔 색조
# plt.style.use('seaborn-dark')  # 어두운 색

# %%
# 기본 산점도
x = np.linspace(0,10,30)
y = np.sin(x)

fig = plt.figure()
ax = plt.axes()
ax.scatter(x,y)
plt.show()

# %%
#  고급 산점도 (버블효과)
rnd = np.random.RandomState(0)

x = rnd.randn(100)
y = rnd.randn(100)

colors = rnd.randn(100)
sizes= 1000*rnd.randn(100)

fig = plt.figure()
ax = plt.axes()
ax.scatter(x,y, s =sizes, alpha=0.9, c= colors)
plt.show()
# Out:
# d:\stacy\py1901\venv\lib\site-packages\matplotlib\collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# iris 데이터셋을 이용해서 버블형 산점도 작성
# x : sepal.length, y: sepal.width
# size : petal.length, color : iris.target

from sklearn import datasets
iris= datasets.load_iris()
data = iris.data
fig = plt.figure()
ax = plt.axes()
ax.scatter(data[:,0], data[:,1],s=50*data[:,2], alpha=0.5, c=iris.target)
plt.show()

# %%
# colors : 0(red), 1(green), 2(blue)

fig = plt.figure()
ax = plt.axes()

# 종 별로 색깔 넣는 방법
# 방법1 - for문 사용
# colors = list(iris.target)
# for i in range(len(colors)):
#     if colors[i] == 0: colors[i] = 'red'
#     elif colors[i] == 1: colors[i] = 'green'
#     elif colors[i] == 2: colors[i] = 'blue'

# 방법2 - pandas 사용
colors =pd.DataFrame(iris.target)
colors[colors==0] = 'red'
colors[colors==1] = 'green'
colors[colors==2] = 'blue'
colors = list(colors.iloc[:,0])

ax.scatter(data[:,0], data[:,1],s=50*data[:,2], alpha=0.45, c=colors)
plt.show()

# %%
# 한 화면에 여러 그래프 그리기 - subplot
# subplot 함수 인자 = 행수/열수/번호
x1 = np.linspace(0,5)
x2 = np.linspace(0,2)

y1 = np.cos(2*np.pi*x1)*np.exp(-x1)
y2=np.cos(2*np.pi*x2)

fig = plt.figure()
plt.subplot(211)  # 2행 1열 공간 중 윗쪽 영역
plt.plot(x1, y1, 'ro--')

plt.subplot(212)  # 2행 1열 공간 중 아래쪽 영역
plt.plot(x2, y2, 'b*-.')

# %%
fig = plt.figure()
plt.subplot(121)  # 1행 2열 공간 중 왼쪽 영역
plt.plot(x1, y1, 'ro--')
plt.subplot(122)  # 1행 2열 공간 중 오른쪽 영역
plt.plot(x2, y2, 'b*-.')

# %%
plt.subplot(221)
plt.plot(np.random.randn(5))
plt.subplot(222)
plt.plot(np.random.randn(5))
plt.subplot(223)
plt.plot(np.random.randn(5))
plt.subplot(224)
plt.plot(np.random.randn(5))
